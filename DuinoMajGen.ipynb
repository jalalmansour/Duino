# %% [markdown]
# <a href="https://colab.research.google.com/github/jalalmansour/Duino/blob/main/DuinoMajGen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/jalalmansour/DuinoMajGen.git
# %cd /content/DuinoMajGen
# !python entry_with_update.py --share --always-high-vram
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 73.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pygit2
#     Found existing installation: pygit2 1.16.0
#     Uninstalling pygit2-1.16.0:
#       Successfully uninstalled pygit2-1.16.0
# ...
# /content
# Cloning into 'DuinoMajGen'...
# remote: Enumerating objects: 6542, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 6542 (delta 8), reused 0 (delta 0), pack-reused 6521 (from 1)
# Receiving objects: 100% (6542/6542), 89.37 MiB | 10.53 MiB/s, done.
# Resolving deltas: 100% (3745/3745), done.
# /content/DuinoMajGen
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# Python 3.10.12 (main, Nov  6 2024, 20:22:13) [GCC 11.4.0]
# Fooocus version: 2.5.5
# Error checking version for torchsde: No package metadata was found for torchsde
# Installing requirements
# ...
